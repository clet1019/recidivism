# %% [markdown]
# <a href="https://colab.research.google.com/github/clet1019/recidivism/blob/main/Competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

df = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
missing_cols = df.columns[df.isnull().any()].tolist()
print("Columns with missing values:", missing_cols)
print(df['Supervision_Level_First'].value_counts())

most_common_offense = df['Prison_Offense'].value_counts().idxmax()
df['Prison_Offense'].fillna(most_common_offense, inplace=True)

most_common_gang = df['Supervision_Level_First'].value_counts().idxmax()
df['Supervision_Level_First'].fillna(most_common_gang, inplace=True)


#gang


most_common_gang = df['Gang_Affiliated'].value_counts().idxmax()
df['Gang_Affiliated'].fillna(most_common_gang, inplace=True)


#replace SRSF
mean_score = df['Supervision_Risk_Score_First'].mean()


df['Supervision_Risk_Score_First'].fillna(mean_score, inplace=True)


#'Avg_Days_per_DrugTest
mean_score = df['Avg_Days_per_DrugTest'].mean()


df['Avg_Days_per_DrugTest'].fillna(mean_score, inplace=True)


#0 columns
columns_to_fill = ['DrugTests_THC_Positive', 'DrugTests_Cocaine_Positive',
                   'DrugTests_Meth_Positive', 'DrugTests_Other_Positive',
                   'Percent_Days_Employed', 'Jobs_Per_Year']


df[columns_to_fill] = df[columns_to_fill].fillna(0)


missing_cols = df.columns[df.isnull().any()].tolist()
print("Columns with missing values:", missing_cols)



#replacing


#offense


most_common_offense = test['Prison_Offense'].value_counts().idxmax()
test['Prison_Offense'].fillna(most_common_offense, inplace=True)



#supervision level


most_common_gang = test['Supervision_Level_First'].value_counts().idxmax()
test['Supervision_Level_First'].fillna(most_common_gang, inplace=True)


#gang


most_common_gang = test['Gang_Affiliated'].value_counts().idxmax()
test['Gang_Affiliated'].fillna(most_common_gang, inplace=True)


#replace SRSF
mean_score = test['Supervision_Risk_Score_First'].mean()


test['Supervision_Risk_Score_First'].fillna(mean_score, inplace=True)


#'Avg_Days_per_DrugTest
mean_score = test['Avg_Days_per_DrugTest'].mean()


test['Avg_Days_per_DrugTest'].fillna(mean_score, inplace=True)




columns_to_fill = ['DrugTests_THC_Positive', 'DrugTests_Cocaine_Positive',
                   'DrugTests_Meth_Positive', 'DrugTests_Other_Positive',
                   'Percent_Days_Employed', 'Jobs_Per_Year']


test[columns_to_fill] = test[columns_to_fill].fillna(mean_score, inplace=True)


missing_cols = test.columns[test.isnull().any()].tolist()


print("Columns with missing values:", missing_cols)


le = LabelEncoder()


for col in df.columns:
    if df[col].dtype == 'object':

        df[col] = le.fit_transform(df[col])




for col in test.columns:

    if test[col].dtype == 'object':

        test[col] = le.fit_transform(test[col])


target_variable = 'Recidivism_Arrest'
feature_columns = [col for col in df.columns if col != 'ID' and col != target_variable]

train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)

X_train = train_data[feature_columns]
y_train = train_data[target_variable]
X_val = val_data[feature_columns]
y_val = val_data[target_variable]

lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

accuracy = accuracy_score(y_val, y_pred)
output.to_csv('predictions_sample.csv', index=False)

print('Accuracy:', accuracy)

# Neural Network

# fix: AttributeError: 'Sequential' object has no attribute 'predict_classes'
# target_variable = 'Recidivism_Arrest'
# feature_columns = [col for col in df.columns if col != 'ID' and col != target_variable]

# train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)

# scaler = StandardScaler()
# X_train = scaler.fit_transform(train_data[feature_columns])
# y_train = train_data[target_variable]
# X_val = scaler.transform(val_data[feature_columns])
# y_val = val_data[target_variable]

# model = Sequential()
# model.add(Dense(units=32, activation='relu', input_dim=X_train.shape[1]))
# model.add(Dense(units=1, activation='sigmoid'))

# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

# y_pred = model.predict(X_val)
# y_pred_classes = y_pred.argmax(axis=-1)

# accuracy = accuracy_score(y_val, y_pred)

# print('Accuracy:', accuracy)
# Out:
# Columns with missing values: ['Gang_Affiliated', 'Supervision_Risk_Score_First', 'Supervision_Level_First', 'Prison_Offense', 'Avg_Days_per_DrugTest', 'DrugTests_THC_Positive', 'DrugTests_Cocaine_Positive', 'DrugTests_Meth_Positive', 'DrugTests_Other_Positive', 'Percent_Days_Employed', 'Jobs_Per_Year']
# Standard       3713
# Specialized    2504
# High           2313
# Name: Supervision_Level_First, dtype: int64
# Columns with missing values: []
# Columns with missing values: ['DrugTests_THC_Positive', 'DrugTests_Cocaine_Positive', 'DrugTests_Meth_Positive', 'DrugTests_Other_Positive', 'Percent_Days_Employed', 'Jobs_Per_Year']
# <ipython-input-15-75e1c1ccf328>:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[columns_to_fill] = test[columns_to_fill].fillna(mean_score, inplace=True)
# ...
